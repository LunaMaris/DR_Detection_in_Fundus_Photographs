# %% [markdown]
# This script can be used to do preprocessing of the fundus images from different databases. The images can have different formats as an input to the preprocessing functions and will eventually be turned into numpy arrays and stored in this format.
#
# For every database a train and test numpy array is generated together with a numpy array containing the corresponding annotation files for training and testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from glob import glob
from skimage.transform import resize
import pandas as pd
from sklearn.model_selection import train_test_split
from resizeimage import resizeimage
import cv2

# %% [markdown]
# The functions below can be used to turn every image into a numpy array and to do preprocessing of the images. The preprocessing function at the end brings all preprocessing steps for one image together.

# %%
def PlotImage(image_array, database = '', image_name = '', save = False, savepath = ''):
    '''Visualize (and save if desired) an image represented by a numpy array'''
    
    plt.figure()
    plt.title(database+': '+image_name)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.imshow(image_array, cmap=plt.cm.Greys_r)
    
    if save == True:
        plt.savefig(savepath+database+'_'+image_name+'.png')
    
    return

# %%
def LoadImage(filepath, plot = False, data_base = '', annotation = False):
    '''Load an image indicated by the filepath and turn it into a numpy array'''
    im = Image.open(filepath)
    im_array = np.asarray(im)
    
    if plot == True:
        if annotation == True:
            PlotImage(im_array, database = data_base, image_name = 'Annotation')
            PlotImage(im_array, database = data_base, image_name = 'Image')
    
    return im_array

# %%
def SelectChannel(image_array, color, plot = False, data_base = ''):
    '''
    For the segmentation of some lesions a particular color channel should be selected
    The possible options for color are 'R', 'G' or 'B'.
    '''
    
    if color == 'R':
        color_channel = image_array[:,:,0]
    
    elif color == 'G':
        color_channel = image_array[:,:,1]
    
    elif color == 'B':
        color_channel = image_array[:,:,2]
        
    else:
        return 'Not a valid color channel!'
    
    if plot == True:
        PlotImage(color_channel, database = data_base, image_name = 'Color Channnel '+ color)
    
    return color_channel

# %%
def FindMask(image_array, plot = False, data_base = ''):
    '''
    defining a binary mask that delineates the retina on the image
    simple thresholding is used for this procedure
    '''
    mask = np.zeros(image_array.shape[0:2])
    
    # in the red channel the difference between background and retina is the largest
    # a threshold of 50 is used, as defined from the histogram below
    red_channel = SelectChannel(image_array, 'R')
    
    # linear contrast mapping is performed when the full intensity range is not used
    intensity_range = np.unique(red_channel)
    if intensity_range[0]!= 0 or intensity_range[-1]!= 255:
        red_channel = cv2.normalize(red_channel, np.zeros(red_channel.shape), alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX)

    retina_positions = np.where(red_channel > 25)
    mask[retina_positions] = 1
    
    if plot == True:
        PlotImage(mask, database = data_base, image_name = 'Retinal Mask')
    
    return mask

# %%
def Cropping(image_array, mask, annotation = False, plot = False, data_base = ''):
    '''
    crop the image according to the found mask
    the smallest bounding box around the retina (as delineated by the mask) is defined
    and the image is cropped to this bounding box
    '''
    
    # define the smallest bounding box around the retina according to the mask
    # define whether there is any value different from 0 on every row and column
    non_zero_row = np.any(mask, axis = 1) # returns a list of true and false
    non_zero_col = np.any(mask, axis = 0)
    
    # define the indiced of the non-zero rows and cols
    non_zero_row_indices = np.where(non_zero_row)[0]
    non_zero_col_indices = np.where(non_zero_col)[0]
    
    # define the indices of the first and last col and row that contain a non-zero value
    lbox = non_zero_col_indices[0]
    rbox = non_zero_col_indices[-1]
    ubox = non_zero_row_indices[0]
    dbox = non_zero_row_indices[-1]
    
    if lbox >= rbox or ubox >= dbox:
        print('Smallest bounding box can not be defined!')
       
    # crop the image and annotation file according to the bounding box
    # in case of an annotation there is only 1 channel
    if annotation:
        cropped_image_array = image_array[ubox:dbox+1, lbox:rbox+1]
        if plot == True:
            PlotImage(cropped_image_array, database = data_base, image_name = 'Cropped Annotation')
        return cropped_image_array
        
    cropped_image_array = image_array[ubox:dbox+1, lbox:rbox+1, :]
    if plot == True:
        PlotImage(cropped_image_array, database = data_base, image_name = 'Cropped Image')
    return cropped_image_array

# %%
def Resizing(image_array, desired_size, plot = False, data_base = '', annotation = False):
    '''Resize the images to the desired shape that is used as an input to the neural network'''
    
    # resizing the image to the desired shape
    image = Image.fromarray(image_array)
    resized_image = resizeimage.resize_cover(image, [desired_size, desired_size], validate=False)
    resized_image_array = np.asarray(resized_image)
    
    if plot == True:
        if annotation == True:
            PlotImage(resized_image_array, database = data_base, image_name = 'Resized Annotation')
        else:
            PlotImage(resized_image_array, database = data_base, image_name = 'Resized Image')
    
    return resized_image_array

# %%
def HistogramEqualization(im_array, plot = False, data_base = ''):
    '''
    This function performs historgram equalization in a local way
    It improves the contrast and it makes the image illumination more uniform
    '''
    clahe = cv2.createCLAHE(clipLimit= 2.0, tileGridSize=(4,4))
    
    x = len(im_array.shape)
    
    if x == 3:
        red_channel = clahe.apply(im_array[:, :, 0])
        green_channel = clahe.apply(im_array[:, :, 1])
        blue_channel = clahe.apply(im_array[:, :, 2])
        equalized_im_array = np.dstack((red_channel, green_channel, blue_channel))
        
    elif x == 2:
        equalized_im_array = clahe.apply(im_array)
        
    if plot == True:
        PlotImage(equalized_im_array, database = data_base, image_name = 'Histogram Equalized Image')
        
    return equalized_im_array

# %%
def Preprocessing(FilePathImage, DesiredSize, FilePathAnnotation = None, selectchannel = None, Plot = False, DataBase = ''):
    '''
    This function preprocesses the image that is found at the given FilePath
    In case there is an annotation image, the path of this annotations should be indicated and
    this annotation image is also preprocessed
    If a channel should be selected selectchannel should have a value of 'R', 'G' or 'B'
    '''
    
    # read in the image and turn into a numpy array
    image_array = LoadImage(FilePathImage, plot = Plot, data_base = DataBase)
    
    # define a binary mask indicating the location of the retina on the image
    mask = FindMask(image_array, plot = Plot, data_base = DataBase)
    
    # crop the image according to the mask 
    cropped_image_array = Cropping(image_array, mask, plot = Plot, data_base = DataBase)
    
    # resize the image according to the predefined size
    resized_image_array = Resizing(cropped_image_array, desired_size = DesiredSize, plot = Plot, data_base = DataBase)

    if selectchannel:
        resized_image_array = SelectChannel(resized_image_array, color = selectchannel, plot = Plot, data_base = DataBase)
        
    # histogram equalization of the image
    resized_image_array_equal = HistogramEqualization(resized_image_array, plot = Plot, data_base = DataBase)
    
    resized_image_array_final = np.expand_dims(resized_image_array_equal, axis = 0)   
    
    # apply the same processing to the corresponding annotation file (if present)
    if FilePathAnnotation:
        annotation_array = LoadImage(FilePathAnnotation, plot = Plot, data_base = DataBase, annotation = True)
        cropped_annotation_array = Cropping(annotation_array, mask, annotation = True, plot = Plot, data_base = DataBase) # same mask as the image
        resized_annotation_array = Resizing(cropped_annotation_array, desired_size = DesiredSize, plot = Plot, data_base = DataBase, annotation = True)
        resized_annotation_array_final = np.expand_dims(resized_annotation_array, axis = 0)
        return resized_image_array_final, resized_annotation_array_final
        

    return resized_image_array_final

# %% [markdown]
# For every database the path for all images (and annotations) now has to be defined such that all images and annotations can be preprocessed and the resulting numpy arrays can be gathered together into training and testing arrays.

# %%
# Define the DataBase you want to preprocess, image and annotation formats are different for different databases

# Kaggle, DR grades
DataBase = 'Kaggle'

# %%
# size to which the images should be resized, here 512 x 512 is chosen
image_size = 256

# %%
def DataPath(database, lesiontype = None):
    '''define the datapath corresponding to the used database'''
    
    print('Defining the data path for the database...')
    datapath = 'C:/Users/lunam/Documents/1steMaster/Stage/Data/' + database + '/'
    
    if lesiontype:
        datapath = datapath + lesiontype + '/'
    
    print('Data path: {}'.format(datapath))
    return datapath

# %%
def FileFormat(database):
    '''Depending on the database, the image and annotation format can be different'''
    
    print('Defining file formats...')
    
    if database == 'IDRiD':
        image_format = '.jpg'
        annotation_format = '.tif'
        
    elif database == 'DRIVE':
        image_format = '.tif'
        annotation_format = '.png'
        
    elif database == 'STARE':
        image_format = '.ppm'
        annotation_format = '.ppm'
        
    elif database == 'CHASEDB1':
        image_format = '.jpg'
        annotation_format = '.png'
        
    elif database == 'Kaggle':
        image_format = '.jpeg'
        # in this case there are no annotations but labels
        annotation_format = None
        
    print('Image format: {}, Annotation_format: {}'.format(image_format, annotation_format))
    return image_format, annotation_format

# %%
def FilePathList(datapath, fileformat):
    '''define a list of the filepaths of the files found in the datapath'''
    
    print('Defining all file paths...')
    filepath_list = glob(datapath + '*' + fileformat)
    
    return filepath_list

# %%
def ArraysImagesLabels(database, ImageSize):
    '''
    This function takes all test and train images and corresponding labels,
    turns them into numpy arrays, preprocesses them and saves them as numpy arrays
    '''
    
    # base datapath of the database
    datapath = DataPath(database)
    
    # path for the images
    path_images = datapath + '/' + 'images' + '/'
    
    # format of the images
    image_format, _ = FileFormat(database)
    
    # define list of all file paths of all images
    path_list_images = FilePathList(path_images, image_format)
    
    # print out the amount of images
    print('Total amount of images: {}'.format(len(path_list_images)))
    
    # go over all images, preprocess them and store them in arrays
    for file_number in range(len(path_list_images)):
        print('Preprocessing image file {}'.format(file_number+1))
        im_path = path_list_images[file_number]
    
        prep_im_array = Preprocessing(im_path, ImageSize)
        
        if file_number == 0:
            im_array = prep_im_array
        else:
            im_array = np.vstack((im_array, prep_im_array))
    
    print('Size of the total image array: {}'.format(im_array.shape))
    
    # load the labels from the csv file
    labels = pd.read_csv(datapath + 'labels.csv')
    # drop the column with image names, we only want the labels
    labels = labels.drop(columns = ['image'])
    # turn labels into a numpy array
    labels = labels.to_numpy()
    labels.flatten()
    labels_array = labels[:,0]
    
    # turn the labels into binary label indicating whether the pathology is more than mild or not
    # everythin higher than 1 is more than mild
    new_labels_array = np.zeros(labels_array.shape)
    more_than_mild_positions = np.where(labels_array >1)
    new_labels_array[more_than_mild_positions] = 1
    
    # one-hot encoding of the labels
    final_labels_array = np.zeros((labels_array.shape[0], 2))

    for position in range(labels_array.shape[0]):
        # (1,0) = more than mild
        if new_labels_array[position] == 1:
            final_labels_array[position,:] = [1,0]
        else:
            final_labels_array[position,:] = [0,1]
    
    print('Size of the total labels array: {}'.format(final_labels_array.shape))  
    
    # save the image and label arrays
    print('Saving the image and label array...')
    np.save(datapath + 'Arrays/' + 'total_images.npy', im_array)
    np.save(datapath + 'Arrays/' + 'total_labels.npy', final_labels_array)
    
    print('Done')

# %%
ArraysImagesLabels(DataBase, ImageSize = image_size)
# Out:
# Defining the data path for the database...
# Data path: C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle/
# Defining file formats...
# Image format: .jpeg, Annotation_format: None
# Defining all file paths...
# Total amount of images: 35126
# Preprocessing image file 1
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10003_left.jpeg
# Preprocessing image file 2
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10003_right.jpeg
# Preprocessing image file 3
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10007_left.jpeg
# Preprocessing image file 4
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10007_right.jpeg
# Preprocessing image file 5
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10009_left.jpeg
# Preprocessing image file 6
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10009_right.jpeg
# Preprocessing image file 7
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1000_left.jpeg
# Preprocessing image file 8
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1000_right.jpeg
# Preprocessing image file 9
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10010_left.jpeg
# Preprocessing image file 10
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10010_right.jpeg
# Preprocessing image file 11
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10013_left.jpeg
# Preprocessing image file 12
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10013_right.jpeg
# Preprocessing image file 13
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10014_left.jpeg
# Preprocessing image file 14
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10014_right.jpeg
# Preprocessing image file 15
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10015_left.jpeg
# Preprocessing image file 16
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10015_right.jpeg
# Preprocessing image file 17
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10017_left.jpeg
# Preprocessing image file 18
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10017_right.jpeg
# Preprocessing image file 19
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10022_left.jpeg
# Preprocessing image file 20
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10022_right.jpeg
# Preprocessing image file 21
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10028_left.jpeg
# Preprocessing image file 22
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10028_right.jpeg
# Preprocessing image file 23
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10029_left.jpeg
# Preprocessing image file 24
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10029_right.jpeg
# Preprocessing image file 25
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1002_left.jpeg
# Preprocessing image file 26
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1002_right.jpeg
# Preprocessing image file 27
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10030_left.jpeg
# Preprocessing image file 28
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10030_right.jpeg
# Preprocessing image file 29
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10031_left.jpeg
# Preprocessing image file 30
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10031_right.jpeg
# Preprocessing image file 31
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10032_left.jpeg
# Preprocessing image file 32
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10032_right.jpeg
# Preprocessing image file 33
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10035_left.jpeg
# Preprocessing image file 34
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10035_right.jpeg
# Preprocessing image file 35
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10042_left.jpeg
# Preprocessing image file 36
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10042_right.jpeg
# Preprocessing image file 37
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10043_left.jpeg
# Preprocessing image file 38
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10043_right.jpeg
# Preprocessing image file 39
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10046_left.jpeg
# Preprocessing image file 40
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10046_right.jpeg
# Preprocessing image file 41
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10047_left.jpeg
# Preprocessing image file 42
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10047_right.jpeg
# Preprocessing image file 43
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10048_left.jpeg
# Preprocessing image file 44
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10048_right.jpeg
# Preprocessing image file 45
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10050_left.jpeg
# Preprocessing image file 46
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10050_right.jpeg
# Preprocessing image file 47
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10053_left.jpeg
# Preprocessing image file 48
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10053_right.jpeg
# Preprocessing image file 49
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10058_left.jpeg
# Preprocessing image file 50
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10058_right.jpeg
# Preprocessing image file 51
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10059_left.jpeg
# Preprocessing image file 52
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10059_right.jpeg
# Preprocessing image file 53
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10061_left.jpeg
# Preprocessing image file 54
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10061_right.jpeg
# Preprocessing image file 55
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10065_left.jpeg
# Preprocessing image file 56
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10065_right.jpeg
# Preprocessing image file 57
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10069_left.jpeg
# Preprocessing image file 58
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10069_right.jpeg
# Preprocessing image file 59
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10073_left.jpeg
# Preprocessing image file 60
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10073_right.jpeg
# Preprocessing image file 61
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10078_left.jpeg
# Preprocessing image file 62
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10078_right.jpeg
# Preprocessing image file 63
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10081_left.jpeg
# Preprocessing image file 64
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10081_right.jpeg
# Preprocessing image file 65
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10085_left.jpeg
# Preprocessing image file 66
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10085_right.jpeg
# Preprocessing image file 67
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1008_left.jpeg
# Preprocessing image file 68
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1008_right.jpeg
# Preprocessing image file 69
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10092_left.jpeg
# Preprocessing image file 70
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10092_right.jpeg
# Preprocessing image file 71
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10094_left.jpeg
# Preprocessing image file 72
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10094_right.jpeg
# Preprocessing image file 73
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10095_left.jpeg
# Preprocessing image file 74
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10095_right.jpeg
# Preprocessing image file 75
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10099_left.jpeg
# Preprocessing image file 76
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10099_right.jpeg
# Preprocessing image file 77
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\100_left.jpeg
# Preprocessing image file 78
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\100_right.jpeg
# Preprocessing image file 79
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10100_left.jpeg
# Preprocessing image file 80
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10100_right.jpeg
# Preprocessing image file 81
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10104_left.jpeg
# Preprocessing image file 82
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10104_right.jpeg
# Preprocessing image file 83
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10109_left.jpeg
# Preprocessing image file 84
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10109_right.jpeg
# Preprocessing image file 85
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10112_left.jpeg
# Preprocessing image file 86
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10112_right.jpeg
# Preprocessing image file 87
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10115_left.jpeg
# Preprocessing image file 88
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10115_right.jpeg
# Preprocessing image file 89
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10116_left.jpeg
# Preprocessing image file 90
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10116_right.jpeg
# Preprocessing image file 91
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1011_left.jpeg
# Preprocessing image file 92
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1011_right.jpeg
# Preprocessing image file 93
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10120_left.jpeg
# Preprocessing image file 94
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10120_right.jpeg
# Preprocessing image file 95
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10124_left.jpeg
# Preprocessing image file 96
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10124_right.jpeg
# Preprocessing image file 97
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10125_left.jpeg
# Preprocessing image file 98
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10125_right.jpeg
# Preprocessing image file 99
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10126_left.jpeg
# Preprocessing image file 100
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10126_right.jpeg
# Preprocessing image file 101
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10129_left.jpeg
# Preprocessing image file 102
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10129_right.jpeg
# Preprocessing image file 103
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1012_left.jpeg
# Preprocessing image file 104
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1012_right.jpeg
# Preprocessing image file 105
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10130_left.jpeg
# Preprocessing image file 106
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10130_right.jpeg
# Preprocessing image file 107
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10131_left.jpeg
# Preprocessing image file 108
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10131_right.jpeg
# Preprocessing image file 109
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10134_left.jpeg
# Preprocessing image file 110
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10134_right.jpeg
# Preprocessing image file 111
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10135_left.jpeg
# Preprocessing image file 112
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10135_right.jpeg
# Preprocessing image file 113
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10137_left.jpeg
# Preprocessing image file 114
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10137_right.jpeg
# Preprocessing image file 115
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10141_left.jpeg
# Preprocessing image file 116
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10141_right.jpeg
# Preprocessing image file 117
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10144_left.jpeg
# Preprocessing image file 118
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10144_right.jpeg
# Preprocessing image file 119
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10147_left.jpeg
# Preprocessing image file 120
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10147_right.jpeg
# Preprocessing image file 121
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10149_left.jpeg
# Preprocessing image file 122
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10149_right.jpeg
# Preprocessing image file 123
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10150_left.jpeg
# Preprocessing image file 124
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10150_right.jpeg
# Preprocessing image file 125
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10153_left.jpeg
# Preprocessing image file 126
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10153_right.jpeg
# Preprocessing image file 127
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10154_left.jpeg
# Preprocessing image file 128
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10154_right.jpeg
# Preprocessing image file 129
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10155_left.jpeg
# Preprocessing image file 130
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10155_right.jpeg
# Preprocessing image file 131
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10156_left.jpeg
# Preprocessing image file 132
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10156_right.jpeg
# Preprocessing image file 133
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10159_left.jpeg
# Preprocessing image file 134
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10159_right.jpeg
# Preprocessing image file 135
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10160_left.jpeg
# Preprocessing image file 136
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10160_right.jpeg
# Preprocessing image file 137
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10161_left.jpeg
# Preprocessing image file 138
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10161_right.jpeg
# Preprocessing image file 139
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10162_left.jpeg
# Preprocessing image file 140
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10162_right.jpeg
# Preprocessing image file 141
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10163_left.jpeg
# Preprocessing image file 142
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10163_right.jpeg
# Preprocessing image file 143
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10166_left.jpeg
# Preprocessing image file 144
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10166_right.jpeg
# Preprocessing image file 145
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10169_left.jpeg
# Preprocessing image file 146
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10169_right.jpeg
# Preprocessing image file 147
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10170_left.jpeg
# Preprocessing image file 148
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10170_right.jpeg
# Preprocessing image file 149
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10173_left.jpeg
# Preprocessing image file 150
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10173_right.jpeg
# Preprocessing image file 151
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10175_left.jpeg
# Preprocessing image file 152
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10175_right.jpeg
# Preprocessing image file 153
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10177_left.jpeg
# Preprocessing image file 154
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10177_right.jpeg
# Preprocessing image file 155
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1017_left.jpeg
# Preprocessing image file 156
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1017_right.jpeg
# Preprocessing image file 157
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10181_left.jpeg
# Preprocessing image file 158
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10181_right.jpeg
# Preprocessing image file 159
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10182_left.jpeg
# Preprocessing image file 160
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10182_right.jpeg
# Preprocessing image file 161
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10183_left.jpeg
# Preprocessing image file 162
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10183_right.jpeg
# Preprocessing image file 163
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10184_left.jpeg
# Preprocessing image file 164
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10184_right.jpeg
# Preprocessing image file 165
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10187_left.jpeg
# Preprocessing image file 166
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10187_right.jpeg
# Preprocessing image file 167
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10190_left.jpeg
# Preprocessing image file 168
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10190_right.jpeg
# Preprocessing image file 169
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10193_left.jpeg
# Preprocessing image file 170
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10193_right.jpeg
# Preprocessing image file 171
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10194_left.jpeg
# Preprocessing image file 172
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10194_right.jpeg
# Preprocessing image file 173
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10199_left.jpeg
# Preprocessing image file 174
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10199_right.jpeg
# Preprocessing image file 175
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10206_left.jpeg
# Preprocessing image file 176
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10206_right.jpeg
# Preprocessing image file 177
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10207_left.jpeg
# Preprocessing image file 178
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10207_right.jpeg
# Preprocessing image file 179
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1020_left.jpeg
# Preprocessing image file 180
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1020_right.jpeg
# Preprocessing image file 181
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10210_left.jpeg
# Preprocessing image file 182
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10210_right.jpeg
# Preprocessing image file 183
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10212_left.jpeg
# Preprocessing image file 184
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10212_right.jpeg
# Preprocessing image file 185
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10218_left.jpeg
# Preprocessing image file 186
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10218_right.jpeg
# Preprocessing image file 187
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1021_left.jpeg
# Preprocessing image file 188
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\1021_right.jpeg
# Preprocessing image file 189
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10220_left.jpeg
# Preprocessing image file 190
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10220_right.jpeg
# Preprocessing image file 191
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10221_left.jpeg
# Preprocessing image file 192
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10221_right.jpeg
# Preprocessing image file 193
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10223_left.jpeg
# Preprocessing image file 194
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10223_right.jpeg
# Preprocessing image file 195
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10224_left.jpeg
# Preprocessing image file 196
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10224_right.jpeg
# Preprocessing image file 197
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10226_left.jpeg
# Preprocessing image file 198
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10226_right.jpeg
# Preprocessing image file 199
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10230_left.jpeg
# Preprocessing image file 200
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10230_right.jpeg
# Preprocessing image file 201
# C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle//images\10232_left.jpeg

# %% [markdown]
# Below some testing of the functions defined above is performed.

# %%
FilePath_im = 'C:/Users/lunam/Documents/1steMaster/Stage/Data/Kaggle/images/13_left.jpeg'
preprocessed_image = Preprocessing(FilePathImage = FilePath_im, DesiredSize = image_size, FilePathAnnotation = None, selectchannel = None, Plot = True, DataBase = 'Kaggle')
